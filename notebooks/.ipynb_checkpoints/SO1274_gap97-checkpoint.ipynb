# %%
# SO 1274: Gap 97

# %%
from DBNets import DBNets2
import matplotlib.pyplot as plt

dbnets = DBNets2()

# %%
file_name = '/Users/kaileyliou/DBNets/images/SO1274_continuum_final.image.pbcor.fits'
centre = (1000, 999)
inclination = 16
pa = 135.6-90
distance = 400.1
rp = 97
res_ba_arcsec = 0.021

# %%
res_sigma = res_ba_arcsec/2.355*distance/rp

# %%
from astropy.io import fits

hdu = fits.open(file_name)[0]
plt.imshow(hdu.data[0,0])
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1999.5), np.float64(1999.5), np.float64(-0.5))

# %%
from DBNets import preproc as pp
deproj_image = pp.deproject_image(file_name, distance, inclination, pa, centre, rp)

# %%
import matplotlib.pyplot as plt
plt.imshow(deproj_image)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(127.5), np.float64(127.5), np.float64(-0.5))

# %%
samples, cs = dbnets(deproj_image, [res_sigma], nsamples=50000)
# Out:
# 100%|███████████████████████████████████| 9963/9963 [00:00<00:00, 18709.93it/s]
# 100%|███████████████████████████████████| 9959/9959 [00:00<00:00, 18237.16it/s]
# 10114it [00:00, 18627.31it/s]
# 100%|███████████████████████████████████| 9955/9955 [00:00<00:00, 18401.59it/s]
# 10100it [00:00, 18812.68it/s]
# loading all data and parameters
# Sample 10 estimates from the posteriror distribution
# Interpolating 10 best estimates
# Standardize data
# FFT
# done.
#  Compute metric..
# DONE!

# %%
import numpy as np
np.median(np.nan_to_num(samples), axis=1)
# Out:
# array([[0.0001616 , 0.06247567, 0.05531757, 0.00023653]])

# %%
from DBNets import utils

# %%
utils.plot_corner(samples[0],name='/Users/kaileyliou/DBNets/images/SO1274_continuum_final.image.pbcor', 
                  savepath='corner.pdf', image = deproj_image, starmass=1e3)

# %%
print(f'Confidence score: {cs[0]:.2f}')
# Out:
# Confidence score: 0.70
